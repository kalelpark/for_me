# %%
import numpy as np
import pandas as pd

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Conv2D, Dropout, Flatten, Activation, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.layers import Concatenate, AveragePooling2D

# %% [markdown]
# # Create Inception Module

# %%
def inception_module(x, filter_1X1, filter_3X3_rd, filter_3X3, filter_5X5_rd, filter_5X5, filter_pool, name = None):
    conv_1X1 = Conv2D(filter_1X1, (1, 1), padding = 'same', activation = 'relu')(x)
    
    conv_3X3 = Conv2D(filter_3X3_rd, (1, 1), padding = 'same', activation = 'relu')(x)
    conv_3X3 = Conv2D(filter_3X3, (3, 3), padding = 'same', activation = 'relu')(conv_3X3)
    
    conv_5X5 = Conv2D(filter_5X5_rd, (1, 1), padding = 'same', activation = 'relu')(x)
    conv_5X5 = Conv2D(filter_5X5, (5, 5), padding = 'same', activation = 'relu')(conv_5X5)
    
    pool_proj = MaxPooling2D((3, 3), strides = (1, 1), padding = 'same')(x)
    pool_proj = Conv2D(filter_pool, (1, 1), padding = 'same', activation = 'relu')(pool_proj)
    
    output = Concatenate(axis = -1, name = name)([conv_1X1, conv_3X3, conv_5X5, pool_proj])
    
    return output

# %% [markdown]
# # Check in advance Inception

# %%
input_tensor = Input(shape = (224, 224,  3))

x = Conv2D(64, (7, 7), padding='same', strides=(2, 2), activation='relu', name='conv_1_7x7/2')(input_tensor)
x = MaxPooling2D((3, 3), padding = 'same', strides = (2, 2), name = 'max_pool_1_3X3/2')(x)
x = Conv2D(64, (1, 1), padding = 'same', strides = (1, 1), activation = 'relu', name = 'conv_2a_3x3/1')(x)
x = Conv2D(192, (3, 3), padding = 'same', strides = (1, 1), activation = 'relu', name='conv_2b_3x3/1')(x)
x = MaxPooling2D((3, 3), padding = 'same', strides = (2, 2), name='max_pool_2_3x3/2')(x)

x = inception_module(x, filter_1X1=64, filter_3X3_rd= 96, filter_3X3=128, filter_5X5_rd= 16, filter_5X5= 32, filter_pool=32, name = 'inception_3a')

model = Model(inputs = input_tensor, outputs = x)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv_1_7x7/2 (Conv2D)           (None, 112, 112, 64) 9472        input_3[0][0]
# __________________________________________________________________________________________________
# max_pool_1_3X3/2 (MaxPooling2D) (None, 56, 56, 64)   0           conv_1_7x7/2[0][0]
# __________________________________________________________________________________________________
# conv_2a_3x3/1 (Conv2D)          (None, 56, 56, 64)   4160        max_pool_1_3X3/2[0][0]
# __________________________________________________________________________________________________
# conv_2b_3x3/1 (Conv2D)          (None, 56, 56, 192)  110784      conv_2a_3x3/1[0][0]
# __________________________________________________________________________________________________
# max_pool_2_3x3/2 (MaxPooling2D) (None, 28, 28, 192)  0           conv_2b_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 28, 28, 96)   18528       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 28, 28, 16)   3088        max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 192)  0           max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 28, 28, 64)   12352       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 128)  110720      conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 28, 28, 32)   12832       conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 28, 28, 32)   6176        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3a (Concatenate)      (None, 28, 28, 256)  0           conv2d_12[0][0]
#                                                                  conv2d_14[0][0]
#                                                                  conv2d_16[0][0]
#                                                                  conv2d_17[0][0]
# ==================================================================================================
# Total params: 288,112
# Trainable params: 288,112
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Making GoogLeNet(Inception Model)

# %%
def create_google_lenet(input_shape = (224, 224, 3), n_classes = 10):
    input_tensor = Input(input_shape)
    
    x = Conv2D(64, (7, 7), padding = 'valid', strides = (2, 2), activation = 'relu', name='conv_1_7x7/2')(input_tensor)
    x = MaxPooling2D((3, 3), strides = (2, 2), name = 'max_pool_1_3x3/2')(x)
    x = Conv2D(64, (1, 1), padding = 'same', strides = (1,1), activation = 'relu', name = 'conv_2a_3x3/1')(x)
    x = Conv2D(192, (3, 3), padding = 'same', strides = (1,1), activation = 'relu', name = 'conv_2b_3x3/1')(x)
    x = MaxPooling2D((3, 3),  strides=(2, 2), name='max_pool_2_3x3/2')(x)
    
    # Inception_3a
    x = inception_module(x, 
                         filter_1X1=64, 
                         filter_3X3_rd=96, 
                         filter_3X3=128, 
                         filter_5X5_rd=16, 
                         filter_5X5=32, 
                         filter_pool=32, 
                         name = 'Inception_3a')
    # Inception_3b
    x = inception_module(x,
                         filter_1X1=128,
                         filter_3X3_rd = 128,
                         filter_3X3=192,
                         filter_5X5_rd=32,
                         filter_5X5=96,
                         filter_pool=64,
                         name = 'Inception_3b')
    
    x = MaxPooling2D((3, 3), strides = (2, 2), name = 'max_pool_3_3x3/2')(x)
    
    # Inception_4a
    x = inception_module(x,
                         filter_1X1=192,
                         filter_3X3_rd=96,
                         filter_3X3=208,
                         filter_5X5_rd=16,
                         filter_5X5=48,
                         filter_pool=64,
                         name = 'Inception_4a')
    
    # Extra NetWork1
    x1 = AveragePooling2D((5, 5), strides = (3, 3))(x)
    x1 = Conv2D(filters = 128, kernel_size = (1, 1), padding = 'same', activation = 'relu')(x1)
    x1 = Flatten()(x1)
    x1 = Dense(1024, activation = 'relu')(x1)
    x1 = Dropout(0.7)(x1)
    x1 = Dense(n_classes, activation = 'softmax')(x1)
    
    # Inception_4b
    x = inception_module(x,
                         filter_1X1=160,
                         filter_3X3_rd=112,
                         filter_3X3=224,
                         filter_5X5_rd=24,
                         filter_5X5=64,
                         filter_pool=64,
                         name = 'Inception_4b')

    # Inception_4c
    x = inception_module(x,
                         filter_1X1=128,
                         filter_3X3_rd=128,
                         filter_3X3=256,
                         filter_5X5_rd=24,
                         filter_5X5=64,
                         filter_pool=64,
                         name = 'Inception_4c')

    # Inception_4d
    x = inception_module(x,
                         filter_1X1=112,
                         filter_3X3_rd=144,
                         filter_3X3=288,
                         filter_5X5_rd=32,
                         filter_5X5=128,
                         filter_pool=128,
                         name = 'Inception_4d')
    # Extra network 2
    x2 = AveragePooling2D(pool_size = (5,5), strides = 3)(x)
    x2 = Conv2D(filters = 128, kernel_size = (1,1), padding = 'same', 
                  activation = 'relu')(x2)
    x2 = Flatten()(x2)
    x2 = Dense(1024, activation = 'relu')(x2)
    x2 = Dropout(0.7)(x2)
    x2 = Dense(n_classes, activation = 'softmax')(x2)
    
    # Inception_4e
    x = inception_module(x,
                         filter_1X1=256,
                         filter_3X3_rd=160,
                         filter_3X3=320,
                         filter_5X5_rd=32,
                         filter_5X5=128,
                         filter_pool=128,
                         name = 'Inception_4e')
    
    x = MaxPooling2D((3, 3), padding = 'same', strides = (2, 2), name = 'max_pool_4_3x3/2')(x)
    
    # inception_5a
    x = inception_module(x,
                         filter_1X1=256,
                         filter_3X3_rd=160,
                         filter_3X3=320,
                         filter_5X5_rd=32,
                         filter_5X5=128,
                         filter_pool=128,
                         name = 'inception_5a')
    # inception_5b
    x = inception_module(x,
                         filter_1X1=384,
                         filter_3X3_rd=192,
                         filter_3X3=384,
                         filter_5X5_rd=48,
                         filter_5X5=128,
                         filter_pool=128,
                         name = 'inception_5b')
    
    x = GlobalAveragePooling2D( name = 'max_pool_5_7x7/1')(x)
    x = Dropout(0.4)(x)
    output = Dense(n_classes, activation = 'softmax', name = 'output')(x)
    
    model = Model(inputs = input_tensor, outputs = [output, x1, x2], name = 'GoogLenet')
    model.summary()
    
    return model

# %%
model = create_google_lenet(input_shape = (224, 224, 3), n_classes = 10)
# Out:
# Model: "GoogLenet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_22 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv_1_7x7/2 (Conv2D)           (None, 109, 109, 64) 9472        input_22[0][0]
# __________________________________________________________________________________________________
# max_pool_1_3x3/2 (MaxPooling2D) (None, 54, 54, 64)   0           conv_1_7x7/2[0][0]
# __________________________________________________________________________________________________
# conv_2a_3x3/1 (Conv2D)          (None, 54, 54, 64)   4160        max_pool_1_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv_2b_3x3/1 (Conv2D)          (None, 54, 54, 192)  110784      conv_2a_3x3/1[0][0]
# __________________________________________________________________________________________________
# max_pool_2_3x3/2 (MaxPooling2D) (None, 26, 26, 192)  0           conv_2b_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d_983 (Conv2D)             (None, 26, 26, 96)   18528       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_985 (Conv2D)             (None, 26, 26, 16)   3088        max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_161 (MaxPooling2D (None, 26, 26, 192)  0           max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_982 (Conv2D)             (None, 26, 26, 64)   12352       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_984 (Conv2D)             (None, 26, 26, 128)  110720      conv2d_983[0][0]
# __________________________________________________________________________________________________
# conv2d_986 (Conv2D)             (None, 26, 26, 32)   12832       conv2d_985[0][0]
# __________________________________________________________________________________________________
# conv2d_987 (Conv2D)             (None, 26, 26, 32)   6176        max_pooling2d_161[0][0]
# __________________________________________________________________________________________________
# Inception_3a (Concatenate)      (None, 26, 26, 256)  0           conv2d_982[0][0]
#                                                                  conv2d_984[0][0]
#                                                                  conv2d_986[0][0]
#                                                                  conv2d_987[0][0]
# __________________________________________________________________________________________________
# conv2d_989 (Conv2D)             (None, 26, 26, 128)  32896       Inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_991 (Conv2D)             (None, 26, 26, 32)   8224        Inception_3a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_162 (MaxPooling2D (None, 26, 26, 256)  0           Inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_988 (Conv2D)             (None, 26, 26, 128)  32896       Inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_990 (Conv2D)             (None, 26, 26, 192)  221376      conv2d_989[0][0]
# __________________________________________________________________________________________________
# conv2d_992 (Conv2D)             (None, 26, 26, 96)   76896       conv2d_991[0][0]
# __________________________________________________________________________________________________
# conv2d_993 (Conv2D)             (None, 26, 26, 64)   16448       max_pooling2d_162[0][0]
# __________________________________________________________________________________________________
# Inception_3b (Concatenate)      (None, 26, 26, 480)  0           conv2d_988[0][0]
#                                                                  conv2d_990[0][0]
#                                                                  conv2d_992[0][0]
#                                                                  conv2d_993[0][0]
# __________________________________________________________________________________________________
# max_pool_3_3x3/2 (MaxPooling2D) (None, 12, 12, 480)  0           Inception_3b[0][0]
# __________________________________________________________________________________________________
# conv2d_995 (Conv2D)             (None, 12, 12, 96)   46176       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_997 (Conv2D)             (None, 12, 12, 16)   7696        max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_163 (MaxPooling2D (None, 12, 12, 480)  0           max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_994 (Conv2D)             (None, 12, 12, 192)  92352       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_996 (Conv2D)             (None, 12, 12, 208)  179920      conv2d_995[0][0]
# __________________________________________________________________________________________________
# conv2d_998 (Conv2D)             (None, 12, 12, 48)   19248       conv2d_997[0][0]
# __________________________________________________________________________________________________
# conv2d_999 (Conv2D)             (None, 12, 12, 64)   30784       max_pooling2d_163[0][0]
# __________________________________________________________________________________________________
# Inception_4a (Concatenate)      (None, 12, 12, 512)  0           conv2d_994[0][0]
#                                                                  conv2d_996[0][0]
#                                                                  conv2d_998[0][0]
#                                                                  conv2d_999[0][0]
# __________________________________________________________________________________________________
# conv2d_1002 (Conv2D)            (None, 12, 12, 112)  57456       Inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_1004 (Conv2D)            (None, 12, 12, 24)   12312       Inception_4a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_164 (MaxPooling2D (None, 12, 12, 512)  0           Inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_1001 (Conv2D)            (None, 12, 12, 160)  82080       Inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_1003 (Conv2D)            (None, 12, 12, 224)  226016      conv2d_1002[0][0]
# __________________________________________________________________________________________________
# conv2d_1005 (Conv2D)            (None, 12, 12, 64)   38464       conv2d_1004[0][0]
# __________________________________________________________________________________________________
# conv2d_1006 (Conv2D)            (None, 12, 12, 64)   32832       max_pooling2d_164[0][0]
# __________________________________________________________________________________________________
# Inception_4b (Concatenate)      (None, 12, 12, 512)  0           conv2d_1001[0][0]
#                                                                  conv2d_1003[0][0]
#                                                                  conv2d_1005[0][0]
#                                                                  conv2d_1006[0][0]
# __________________________________________________________________________________________________
# conv2d_1008 (Conv2D)            (None, 12, 12, 128)  65664       Inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_1010 (Conv2D)            (None, 12, 12, 24)   12312       Inception_4b[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_165 (MaxPooling2D (None, 12, 12, 512)  0           Inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_1007 (Conv2D)            (None, 12, 12, 128)  65664       Inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_1009 (Conv2D)            (None, 12, 12, 256)  295168      conv2d_1008[0][0]
# __________________________________________________________________________________________________
# conv2d_1011 (Conv2D)            (None, 12, 12, 64)   38464       conv2d_1010[0][0]
# __________________________________________________________________________________________________
# conv2d_1012 (Conv2D)            (None, 12, 12, 64)   32832       max_pooling2d_165[0][0]
# __________________________________________________________________________________________________
# Inception_4c (Concatenate)      (None, 12, 12, 512)  0           conv2d_1007[0][0]
#                                                                  conv2d_1009[0][0]
#                                                                  conv2d_1011[0][0]
#                                                                  conv2d_1012[0][0]
# __________________________________________________________________________________________________
# conv2d_1014 (Conv2D)            (None, 12, 12, 144)  73872       Inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_1016 (Conv2D)            (None, 12, 12, 32)   16416       Inception_4c[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_166 (MaxPooling2D (None, 12, 12, 512)  0           Inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_1013 (Conv2D)            (None, 12, 12, 112)  57456       Inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_1015 (Conv2D)            (None, 12, 12, 288)  373536      conv2d_1014[0][0]
# __________________________________________________________________________________________________
# conv2d_1017 (Conv2D)            (None, 12, 12, 128)  102528      conv2d_1016[0][0]
# __________________________________________________________________________________________________
# conv2d_1018 (Conv2D)            (None, 12, 12, 128)  65664       max_pooling2d_166[0][0]
# __________________________________________________________________________________________________
# Inception_4d (Concatenate)      (None, 12, 12, 656)  0           conv2d_1013[0][0]
#                                                                  conv2d_1015[0][0]
#                                                                  conv2d_1017[0][0]
#                                                                  conv2d_1018[0][0]
# __________________________________________________________________________________________________
# conv2d_1021 (Conv2D)            (None, 12, 12, 160)  105120      Inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_1023 (Conv2D)            (None, 12, 12, 32)   21024       Inception_4d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_167 (MaxPooling2D (None, 12, 12, 656)  0           Inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_1020 (Conv2D)            (None, 12, 12, 256)  168192      Inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_1022 (Conv2D)            (None, 12, 12, 320)  461120      conv2d_1021[0][0]
# __________________________________________________________________________________________________
# conv2d_1024 (Conv2D)            (None, 12, 12, 128)  102528      conv2d_1023[0][0]
# __________________________________________________________________________________________________
# conv2d_1025 (Conv2D)            (None, 12, 12, 128)  84096       max_pooling2d_167[0][0]
# __________________________________________________________________________________________________
# Inception_4e (Concatenate)      (None, 12, 12, 832)  0           conv2d_1020[0][0]
#                                                                  conv2d_1022[0][0]
#                                                                  conv2d_1024[0][0]
#                                                                  conv2d_1025[0][0]
# __________________________________________________________________________________________________
# max_pool_4_3x3/2 (MaxPooling2D) (None, 6, 6, 832)    0           Inception_4e[0][0]
# __________________________________________________________________________________________________
# conv2d_1027 (Conv2D)            (None, 6, 6, 160)    133280      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_1029 (Conv2D)            (None, 6, 6, 32)     26656       max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_168 (MaxPooling2D (None, 6, 6, 832)    0           max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_1026 (Conv2D)            (None, 6, 6, 256)    213248      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_1028 (Conv2D)            (None, 6, 6, 320)    461120      conv2d_1027[0][0]
# __________________________________________________________________________________________________
# conv2d_1030 (Conv2D)            (None, 6, 6, 128)    102528      conv2d_1029[0][0]
# __________________________________________________________________________________________________
# conv2d_1031 (Conv2D)            (None, 6, 6, 128)    106624      max_pooling2d_168[0][0]
# __________________________________________________________________________________________________
# inception_5a (Concatenate)      (None, 6, 6, 832)    0           conv2d_1026[0][0]
#                                                                  conv2d_1028[0][0]
#                                                                  conv2d_1030[0][0]
#                                                                  conv2d_1031[0][0]
# __________________________________________________________________________________________________
# conv2d_1033 (Conv2D)            (None, 6, 6, 192)    159936      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_1035 (Conv2D)            (None, 6, 6, 48)     39984       inception_5a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_169 (MaxPooling2D (None, 6, 6, 832)    0           inception_5a[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_16 (AveragePo (None, 3, 3, 512)    0           Inception_4a[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_17 (AveragePo (None, 3, 3, 656)    0           Inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_1032 (Conv2D)            (None, 6, 6, 384)    319872      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_1034 (Conv2D)            (None, 6, 6, 384)    663936      conv2d_1033[0][0]
# __________________________________________________________________________________________________
# conv2d_1036 (Conv2D)            (None, 6, 6, 128)    153728      conv2d_1035[0][0]
# __________________________________________________________________________________________________
# conv2d_1037 (Conv2D)            (None, 6, 6, 128)    106624      max_pooling2d_169[0][0]
# __________________________________________________________________________________________________
# conv2d_1000 (Conv2D)            (None, 3, 3, 128)    65664       average_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_1019 (Conv2D)            (None, 3, 3, 128)    84096       average_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# inception_5b (Concatenate)      (None, 6, 6, 1024)   0           conv2d_1032[0][0]
#                                                                  conv2d_1034[0][0]
#                                                                  conv2d_1036[0][0]
#                                                                  conv2d_1037[0][0]
# __________________________________________________________________________________________________
# flatten_16 (Flatten)            (None, 1152)         0           conv2d_1000[0][0]
# __________________________________________________________________________________________________
# flatten_17 (Flatten)            (None, 1152)         0           conv2d_1019[0][0]
# __________________________________________________________________________________________________
# max_pool_5_7x7/1 (GlobalAverage (None, 1024)         0           inception_5b[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 1024)         1180672     flatten_16[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 1024)         1180672     flatten_17[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 1024)         0           max_pool_5_7x7/1[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 1024)         0           dense_32[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 1024)         0           dense_34[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 10)           10250       dropout_29[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 10)           10250       dropout_27[0][0]
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 10)           10250       dropout_28[0][0]
# ==================================================================================================
# Total params: 8,673,230
# Trainable params: 8,673,230
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
Image_size = 128
batch_size = 64

# %% [markdown]
# # Learning for Model

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import Sequence
import cv2
import sklearn

def zero_one_scaler(image):
    return image / 255.0

def get_preprocessed_ohe(images, label, pre_func = None):
    if pre_func is not None:
        images = pre_func(images)
    oh_labels = to_categorical(label)
    return images, oh_labels

def get_train_valid_test(train_images, train_labels, test_images, test_labels, valid_size = 0.15, random_state = 256):
    train_images, train_labels = get_preprocessed_ohe(train_images, train_labels)
    test_images, test_labels = get_preprocessed_ohe(test_images, test_labels)
    
    train_images, valid_images, train_labels, valid_labels = train_test_split(train_images, train_labels, test_size = valid_size, random_state =random_state)
    
    return (train_images, train_labels), (valid_images, valid_labels), (test_images, test_labels)


class CIFAR_Dataset(Sequence):
    def __init__(self, images_array, labels, batch_size = batch_size, augmentator = None,  pre_func = None):
        self.images_array = images_array
        self.labels = labels
        self.batch_size = batch_size
        self.augmentator = augmentator
        self.pre_func = pre_func
        
    def __len__(self):
        return int(np.ceil(len(self.labels) / self.batch_size))
    
    def __getitem__(self, index):
        images_fetch = self.images_array[index*self.batch_size:(index+1)*self.batch_size]
        
        if self.labels is not None:
            label_batch = self.labels[index*self.batch_size:(index+1)*self.batch_size]
        
        image_batch = np.zeros((images_fetch.shape[0], Image_size, Image_size, 3), dtype = 'float32')
        
        for image_index in range(images_fetch.shape[0]):
            image = cv2.resize(images_fetch[image_index], (Image_size, Image_size))
            if self.augmentator is not None:
                image = self.augmentator(image = image)['image']
            
            if self.pre_func is not None:
                image = self.pre_func(image)
            
            image_batch[image_index] = image
        
        return image_batch, label_batch

# %%
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
print(train_images.shape, train_labels.shape, test_images.shape, test_labels.shape)

(train_images, train_labels), (valid_images, valid_labels), (test_images, test_oh_labels) = \
    get_train_valid_test(train_images, train_labels, test_images, test_labels, valid_size=0.15, random_state=2021)
print(train_images.shape, train_labels.shape, valid_images.shape, valid_labels.shape, test_images.shape, test_oh_labels.shape)
# Out:
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)
# (42500, 32, 32, 3) (42500, 10) (7500, 32, 32, 3) (7500, 10) (10000, 32, 32, 3) (10000, 10)

# %%
from tensorflow.keras.applications.inception_v3 import preprocess_input as Inception_preprocess

train_dir = CIFAR_Dataset(train_images, train_labels, pre_func= Inception_preprocess)
valid_dir = CIFAR_Dataset(valid_images, valid_labels, pre_func= Inception_preprocess)

# %%
model = create_google_lenet(input_shape = (128, 128, 3), n_classes = 10)
# Out:
# Model: "GoogLenet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_24 (InputLayer)           [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv_1_7x7/2 (Conv2D)           (None, 61, 61, 64)   9472        input_24[0][0]
# __________________________________________________________________________________________________
# max_pool_1_3x3/2 (MaxPooling2D) (None, 30, 30, 64)   0           conv_1_7x7/2[0][0]
# __________________________________________________________________________________________________
# conv_2a_3x3/1 (Conv2D)          (None, 30, 30, 64)   4160        max_pool_1_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv_2b_3x3/1 (Conv2D)          (None, 30, 30, 192)  110784      conv_2a_3x3/1[0][0]
# __________________________________________________________________________________________________
# max_pool_2_3x3/2 (MaxPooling2D) (None, 14, 14, 192)  0           conv_2b_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d_1095 (Conv2D)            (None, 14, 14, 96)   18528       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_1097 (Conv2D)            (None, 14, 14, 16)   3088        max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_179 (MaxPooling2D (None, 14, 14, 192)  0           max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_1094 (Conv2D)            (None, 14, 14, 64)   12352       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_1096 (Conv2D)            (None, 14, 14, 128)  110720      conv2d_1095[0][0]
# __________________________________________________________________________________________________
# conv2d_1098 (Conv2D)            (None, 14, 14, 32)   12832       conv2d_1097[0][0]
# __________________________________________________________________________________________________
# conv2d_1099 (Conv2D)            (None, 14, 14, 32)   6176        max_pooling2d_179[0][0]
# __________________________________________________________________________________________________
# Inception_3a (Concatenate)      (None, 14, 14, 256)  0           conv2d_1094[0][0]
#                                                                  conv2d_1096[0][0]
#                                                                  conv2d_1098[0][0]
#                                                                  conv2d_1099[0][0]
# __________________________________________________________________________________________________
# conv2d_1101 (Conv2D)            (None, 14, 14, 128)  32896       Inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_1103 (Conv2D)            (None, 14, 14, 32)   8224        Inception_3a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_180 (MaxPooling2D (None, 14, 14, 256)  0           Inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_1100 (Conv2D)            (None, 14, 14, 128)  32896       Inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_1102 (Conv2D)            (None, 14, 14, 192)  221376      conv2d_1101[0][0]
# __________________________________________________________________________________________________
# conv2d_1104 (Conv2D)            (None, 14, 14, 96)   76896       conv2d_1103[0][0]
# __________________________________________________________________________________________________
# conv2d_1105 (Conv2D)            (None, 14, 14, 64)   16448       max_pooling2d_180[0][0]
# __________________________________________________________________________________________________
# Inception_3b (Concatenate)      (None, 14, 14, 480)  0           conv2d_1100[0][0]
#                                                                  conv2d_1102[0][0]
#                                                                  conv2d_1104[0][0]
#                                                                  conv2d_1105[0][0]
# __________________________________________________________________________________________________
# max_pool_3_3x3/2 (MaxPooling2D) (None, 6, 6, 480)    0           Inception_3b[0][0]
# __________________________________________________________________________________________________
# conv2d_1107 (Conv2D)            (None, 6, 6, 96)     46176       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_1109 (Conv2D)            (None, 6, 6, 16)     7696        max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_181 (MaxPooling2D (None, 6, 6, 480)    0           max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_1106 (Conv2D)            (None, 6, 6, 192)    92352       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_1108 (Conv2D)            (None, 6, 6, 208)    179920      conv2d_1107[0][0]
# __________________________________________________________________________________________________
# conv2d_1110 (Conv2D)            (None, 6, 6, 48)     19248       conv2d_1109[0][0]
# __________________________________________________________________________________________________
# conv2d_1111 (Conv2D)            (None, 6, 6, 64)     30784       max_pooling2d_181[0][0]
# __________________________________________________________________________________________________
# Inception_4a (Concatenate)      (None, 6, 6, 512)    0           conv2d_1106[0][0]
#                                                                  conv2d_1108[0][0]
#                                                                  conv2d_1110[0][0]
#                                                                  conv2d_1111[0][0]
# __________________________________________________________________________________________________
# conv2d_1114 (Conv2D)            (None, 6, 6, 112)    57456       Inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_1116 (Conv2D)            (None, 6, 6, 24)     12312       Inception_4a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_182 (MaxPooling2D (None, 6, 6, 512)    0           Inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_1113 (Conv2D)            (None, 6, 6, 160)    82080       Inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_1115 (Conv2D)            (None, 6, 6, 224)    226016      conv2d_1114[0][0]
# __________________________________________________________________________________________________
# conv2d_1117 (Conv2D)            (None, 6, 6, 64)     38464       conv2d_1116[0][0]
# __________________________________________________________________________________________________
# conv2d_1118 (Conv2D)            (None, 6, 6, 64)     32832       max_pooling2d_182[0][0]
# __________________________________________________________________________________________________
# Inception_4b (Concatenate)      (None, 6, 6, 512)    0           conv2d_1113[0][0]
#                                                                  conv2d_1115[0][0]
#                                                                  conv2d_1117[0][0]
#                                                                  conv2d_1118[0][0]
# __________________________________________________________________________________________________
# conv2d_1120 (Conv2D)            (None, 6, 6, 128)    65664       Inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_1122 (Conv2D)            (None, 6, 6, 24)     12312       Inception_4b[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_183 (MaxPooling2D (None, 6, 6, 512)    0           Inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_1119 (Conv2D)            (None, 6, 6, 128)    65664       Inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_1121 (Conv2D)            (None, 6, 6, 256)    295168      conv2d_1120[0][0]
# __________________________________________________________________________________________________
# conv2d_1123 (Conv2D)            (None, 6, 6, 64)     38464       conv2d_1122[0][0]
# __________________________________________________________________________________________________
# conv2d_1124 (Conv2D)            (None, 6, 6, 64)     32832       max_pooling2d_183[0][0]
# __________________________________________________________________________________________________
# Inception_4c (Concatenate)      (None, 6, 6, 512)    0           conv2d_1119[0][0]
#                                                                  conv2d_1121[0][0]
#                                                                  conv2d_1123[0][0]
#                                                                  conv2d_1124[0][0]
# __________________________________________________________________________________________________
# conv2d_1126 (Conv2D)            (None, 6, 6, 144)    73872       Inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_1128 (Conv2D)            (None, 6, 6, 32)     16416       Inception_4c[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_184 (MaxPooling2D (None, 6, 6, 512)    0           Inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_1125 (Conv2D)            (None, 6, 6, 112)    57456       Inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_1127 (Conv2D)            (None, 6, 6, 288)    373536      conv2d_1126[0][0]
# __________________________________________________________________________________________________
# conv2d_1129 (Conv2D)            (None, 6, 6, 128)    102528      conv2d_1128[0][0]
# __________________________________________________________________________________________________
# conv2d_1130 (Conv2D)            (None, 6, 6, 128)    65664       max_pooling2d_184[0][0]
# __________________________________________________________________________________________________
# Inception_4d (Concatenate)      (None, 6, 6, 656)    0           conv2d_1125[0][0]
#                                                                  conv2d_1127[0][0]
#                                                                  conv2d_1129[0][0]
#                                                                  conv2d_1130[0][0]
# __________________________________________________________________________________________________
# conv2d_1133 (Conv2D)            (None, 6, 6, 160)    105120      Inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_1135 (Conv2D)            (None, 6, 6, 32)     21024       Inception_4d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_185 (MaxPooling2D (None, 6, 6, 656)    0           Inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_1132 (Conv2D)            (None, 6, 6, 256)    168192      Inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_1134 (Conv2D)            (None, 6, 6, 320)    461120      conv2d_1133[0][0]
# __________________________________________________________________________________________________
# conv2d_1136 (Conv2D)            (None, 6, 6, 128)    102528      conv2d_1135[0][0]
# __________________________________________________________________________________________________
# conv2d_1137 (Conv2D)            (None, 6, 6, 128)    84096       max_pooling2d_185[0][0]
# __________________________________________________________________________________________________
# Inception_4e (Concatenate)      (None, 6, 6, 832)    0           conv2d_1132[0][0]
#                                                                  conv2d_1134[0][0]
#                                                                  conv2d_1136[0][0]
#                                                                  conv2d_1137[0][0]
# __________________________________________________________________________________________________
# max_pool_4_3x3/2 (MaxPooling2D) (None, 3, 3, 832)    0           Inception_4e[0][0]
# __________________________________________________________________________________________________
# conv2d_1139 (Conv2D)            (None, 3, 3, 160)    133280      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_1141 (Conv2D)            (None, 3, 3, 32)     26656       max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_186 (MaxPooling2D (None, 3, 3, 832)    0           max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_1138 (Conv2D)            (None, 3, 3, 256)    213248      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_1140 (Conv2D)            (None, 3, 3, 320)    461120      conv2d_1139[0][0]
# __________________________________________________________________________________________________
# conv2d_1142 (Conv2D)            (None, 3, 3, 128)    102528      conv2d_1141[0][0]
# __________________________________________________________________________________________________
# conv2d_1143 (Conv2D)            (None, 3, 3, 128)    106624      max_pooling2d_186[0][0]
# __________________________________________________________________________________________________
# inception_5a (Concatenate)      (None, 3, 3, 832)    0           conv2d_1138[0][0]
#                                                                  conv2d_1140[0][0]
#                                                                  conv2d_1142[0][0]
#                                                                  conv2d_1143[0][0]
# __________________________________________________________________________________________________
# conv2d_1145 (Conv2D)            (None, 3, 3, 192)    159936      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_1147 (Conv2D)            (None, 3, 3, 48)     39984       inception_5a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_187 (MaxPooling2D (None, 3, 3, 832)    0           inception_5a[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_20 (AveragePo (None, 1, 1, 512)    0           Inception_4a[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_21 (AveragePo (None, 1, 1, 656)    0           Inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_1144 (Conv2D)            (None, 3, 3, 384)    319872      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_1146 (Conv2D)            (None, 3, 3, 384)    663936      conv2d_1145[0][0]
# __________________________________________________________________________________________________
# conv2d_1148 (Conv2D)            (None, 3, 3, 128)    153728      conv2d_1147[0][0]
# __________________________________________________________________________________________________
# conv2d_1149 (Conv2D)            (None, 3, 3, 128)    106624      max_pooling2d_187[0][0]
# __________________________________________________________________________________________________
# conv2d_1112 (Conv2D)            (None, 1, 1, 128)    65664       average_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_1131 (Conv2D)            (None, 1, 1, 128)    84096       average_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# inception_5b (Concatenate)      (None, 3, 3, 1024)   0           conv2d_1144[0][0]
#                                                                  conv2d_1146[0][0]
#                                                                  conv2d_1148[0][0]
#                                                                  conv2d_1149[0][0]
# __________________________________________________________________________________________________
# flatten_20 (Flatten)            (None, 128)          0           conv2d_1112[0][0]
# __________________________________________________________________________________________________
# flatten_21 (Flatten)            (None, 128)          0           conv2d_1131[0][0]
# __________________________________________________________________________________________________
# max_pool_5_7x7/1 (GlobalAverage (None, 1024)         0           inception_5b[0][0]
# __________________________________________________________________________________________________
# dense_40 (Dense)                (None, 1024)         132096      flatten_20[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 1024)         132096      flatten_21[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 1024)         0           max_pool_5_7x7/1[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 1024)         0           dense_40[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 1024)         0           dense_42[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 10)           10250       dropout_35[0][0]
# __________________________________________________________________________________________________
# dense_41 (Dense)                (None, 10)           10250       dropout_33[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 10)           10250       dropout_34[0][0]
# ==================================================================================================
# Total params: 6,576,078
# Trainable params: 6,576,078
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate= 0.0001), loss = 'categorical_crossentropy', metrics = ['accuracy'])
rlr_cb = ReduceLROnPlateau(monitor='val_loss', factor = 0.2, patience = 3, mode = 'min', verbose = 1)
elr_cb = EarlyStopping(monitor = 'val_loss', patience= 10, mode = 'min', verbose= 1)
model.fit(train_dir, validation_data= valid_dir, epochs= 30, callbacks= [rlr_cb, elr_cb])
# Out:
# Epoch 1/30
# 665/665 [==============================] - 41s 55ms/step - loss: 5.6373 - output_loss: 1.8294 - dense_41_loss: 1.9293 - dense_43_loss: 1.8787 - output_accuracy: 0.3040 - dense_41_accuracy: 0.2505 - dense_43_accuracy: 0.2797 - val_loss: 4.7116 - val_output_loss: 1.5221 - val_dense_41_loss: 1.6466 - val_dense_43_loss: 1.5429 - val_output_accuracy: 0.4284 - val_dense_41_accuracy: 0.3793 - val_dense_43_accuracy: 0.4204
# Epoch 2/30
# 665/665 [==============================] - 34s 52ms/step - loss: 4.5699 - output_loss: 1.4696 - dense_41_loss: 1.5994 - dense_43_loss: 1.5009 - output_accuracy: 0.4584 - dense_41_accuracy: 0.3870 - dense_43_accuracy: 0.4434 - val_loss: 4.2432 - val_output_loss: 1.3933 - val_dense_41_loss: 1.4724 - val_dense_43_loss: 1.3775 - val_output_accuracy: 0.4952 - val_dense_41_accuracy: 0.4505 - val_dense_43_accuracy: 0.5039
# Epoch 3/30
# 665/665 [==============================] - 34s 51ms/step - loss: 3.9918 - output_loss: 1.2776 - dense_41_loss: 1.4083 - dense_43_loss: 1.3059 - output_accuracy: 0.5360 - dense_41_accuracy: 0.4756 - dense_43_accuracy: 0.5270 - val_loss: 3.6070 - val_output_loss: 1.1651 - val_dense_41_loss: 1.2755 - val_dense_43_loss: 1.1664 - val_output_accuracy: 0.5727 - val_dense_41_accuracy: 0.5320 - val_dense_43_accuracy: 0.5812
# Epoch 23/30
# 665/665 [==============================] - 35s 52ms/step - loss: 0.4453 - output_loss: 0.0337 - dense_41_loss: 0.3537 - dense_43_loss: 0.0579 - output_accuracy: 0.9885 - dense_41_accuracy: 0.8791 - dense_43_accuracy: 0.9829 - val_loss: 2.3264 - val_output_loss: 0.9829 - val_dense_41_loss: 0.5970 - val_dense_43_loss: 0.7465 - val_output_accuracy: 0.8236 - val_dense_41_accuracy: 0.8017 - val_dense_43_accuracy: 0.8261
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# Epoch 24/30
# 665/665 [==============================] - 35s 52ms/step - loss: 0.3862 - output_loss: 0.0176 - dense_41_loss: 0.3318 - dense_43_loss: 0.0369 - output_accuracy: 0.9952 - dense_41_accuracy: 0.8873 - dense_43_accuracy: 0.9906 - val_loss: 2.3816 - val_output_loss: 1.0297 - val_dense_41_loss: 0.5895 - val_dense_43_loss: 0.7625 - val_output_accuracy: 0.8257 - val_dense_41_accuracy: 0.8088 - val_dense_43_accuracy: 0.8293
# Epoch 25/30
# 665/665 [==============================] - 35s 52ms/step - loss: 0.3763 - output_loss: 0.0143 - dense_41_loss: 0.3285 - dense_43_loss: 0.0335 - output_accuracy: 0.9964 - dense_41_accuracy: 0.8886 - dense_43_accuracy: 0.9918 - val_loss: 2.4543 - val_output_loss: 1.0799 - val_dense_41_loss: 0.5908 - val_dense_43_loss: 0.7837 - val_output_accuracy: 0.8280 - val_dense_41_accuracy: 0.8085 - val_dense_43_accuracy: 0.8319
# Epoch 26/30
# 665/665 [==============================] - 35s 53ms/step - loss: 0.3667 - output_loss: 0.0123 - dense_41_loss: 0.3233 - dense_43_loss: 0.0312 - output_accuracy: 0.9969 - dense_41_accuracy: 0.8892 - dense_43_accuracy: 0.9922 - val_loss: 2.5361 - val_output_loss: 1.1359 - val_dense_41_loss: 0.5942 - val_dense_43_loss: 0.8060 - val_output_accuracy: 0.8235 - val_dense_41_accuracy: 0.8071 - val_dense_43_accuracy: 0.8288
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# Epoch 27/30
# 665/665 [==============================] - 34s 52ms/step - loss: 0.3550 - output_loss: 0.0096 - dense_41_loss: 0.3188 - dense_43_loss: 0.0266 - output_accuracy: 0.9979 - dense_41_accuracy: 0.8918 - dense_43_accuracy: 0.9941 - val_loss: 2.5456 - val_output_loss: 1.1439 - val_dense_41_loss: 0.5918 - val_dense_43_loss: 0.8098 - val_output_accuracy: 0.8249 - val_dense_41_accuracy: 0.8092 - val_dense_43_accuracy: 0.8300
# Epoch 00027: early stopping

# %%
test_dir = CIFAR_Dataset(test_images, test_oh_labels, batch_size =  batch_size, pre_func= Inception_preprocess)
evaluate = model.evaluate(test_dir)
# Out:
# 157/157 [==============================] - 3s 18ms/step - loss: 2.6567 - output_loss: 1.1943 - dense_41_loss: 0.6118 - dense_43_loss: 0.8506 - output_accuracy: 0.8180 - dense_41_accuracy: 0.7998 - dense_43_accuracy: 0.8206
